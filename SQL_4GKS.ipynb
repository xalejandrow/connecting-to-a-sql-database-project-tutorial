# %% [markdown]
# <a href="https://colab.research.google.com/github/xalejandrow/connecting-to-a-sql-database-project-tutorial/blob/main/SQL_4GKS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandasql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from pandasql import sqldf
df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    193573 non-null  object
#  1   continent                                   182330 non-null  object
#  2   location                                    193573 non-null  object
#  3   date                                        193573 non-null  object
#  4   total_cases                                 185895 non-null  float64
#  5   new_cases                                   185611 non-null  float64
#  6   new_cases_smoothed                          184437 non-null  float64
#  7   total_deaths                                167374 non-null  float64
#  8   new_deaths                                  167358 non-null  float64
# ...

# %%
sqldf("select * from df limit 10")
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0                 NaN         None       None                None  ...
# ...

# %%
sqldf("select location, new_cases from df limit 10")
# Out:
#       location  new_cases
# 0  Afghanistan        5.0
# 1  Afghanistan        0.0
# 2  Afghanistan        0.0
# 3  Afghanistan        0.0
# 4  Afghanistan        0.0
# 5  Afghanistan        0.0
# 6  Afghanistan        0.0
# 7  Afghanistan        0.0
# 8  Afghanistan        0.0
# 9  Afghanistan        0.0

# %%
sqldf("select location, new_cases from df where location = 'Uruguay'")
# Out:
#     location  new_cases
# 0    Uruguay        4.0
# 1    Uruguay        2.0
# 2    Uruguay        2.0
# 3    Uruguay       21.0
# 4    Uruguay       21.0
# ..       ...        ...
# 817  Uruguay        NaN
# 818  Uruguay        NaN
# 819  Uruguay        NaN
# 820  Uruguay        NaN
# 821  Uruguay        NaN
#
# [822 rows x 2 columns]

# %%
sqldf("select location, new_cases, date from df where location = 'Uruguay' limit 10")
# Out:
#   location  new_cases        date
# 0  Uruguay        4.0  2020-03-13
# 1  Uruguay        2.0  2020-03-14
# 2  Uruguay        2.0  2020-03-15
# 3  Uruguay       21.0  2020-03-16
# 4  Uruguay       21.0  2020-03-17
# 5  Uruguay       29.0  2020-03-18
# 6  Uruguay       15.0  2020-03-19
# 7  Uruguay       16.0  2020-03-20
# 8  Uruguay       25.0  2020-03-21
# 9  Uruguay       23.0  2020-03-22

# %%
sqldf("select location, new_cases, date from df where location = 'Uruguay' order by date desc limit 10")
# Out:
#   location  new_cases        date
# 0  Uruguay        NaN  2022-06-12
# 1  Uruguay        NaN  2022-06-11
# 2  Uruguay        NaN  2022-06-10
# 3  Uruguay        NaN  2022-06-09
# 4  Uruguay        NaN  2022-06-08
# 5  Uruguay     9184.0  2022-06-07
# 6  Uruguay        0.0  2022-06-06
# 7  Uruguay        0.0  2022-06-05
# 8  Uruguay        0.0  2022-06-04
# 9  Uruguay        0.0  2022-06-03
